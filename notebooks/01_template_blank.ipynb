# %% [markdown]
# # VMPD Analysis: [Regime Name Here]
#
# **Vulnerability Management for Policy Design (VMPD) v1.0**
#
# This is a blank template. To use it for your own analysis:
#
# 1. Save a copy of this notebook with a descriptive name (e.g., `03_my_analysis_GDPR.ipynb`)
# 2. Replace the regime name above and the regime context cell below with your own information
# 3. Work through the five examinations, adding vulnerabilities as you identify them
# 4. Generate the final report at the end
#
# Refer to `methodology/VMPD_methodology.md` for the full methodology, and `00_start_here.ipynb` for orientation. To see a complete worked example, see `02_worked_example_pipeline_attestation.ipynb`.

# %% [markdown]
# ## Setup
#
# Run this cell once at the start. It loads the VMPD engine.

# %%
import sys
sys.path.append('../src')
from vmpd_engine import *

# %% [markdown]
# ## Regime context
#
# Fill in the basic information about the regime you are analysing.

# %%
analysis = new_analysis(
    regime_name='[Name of the regime, e.g. EU AI Act, GDPR, AIDA, Treasury Board Directive on ADM]',
    analyst='[Your name]',
    operational_context='[Describe the operational context: actors involved in implementation, systems or activities being governed, populations affected, existing institutional architecture.]',
    accountability_frame='[Describe the explicit or implicit claims the regime makes about who is responsible for what outcomes, including outcomes the regime does not directly address but which fall within its scope of concern.]'
)

# %% [markdown]
# ---
#
# ## Examination 1: Legibility Analysis
#
# **Question:** What conditions, processes, or system behaviours does the regime depend on but cannot see?
#
# Identify each invisible condition as a separate vulnerability. For each, score the four sub-metrics on a 0–4 scale.
#
# Run the cell below to see the scoring criteria for this dimension:

# %%
show_criteria('legibility')

# %%
# Add a legibility vulnerability
# Duplicate this cell for each additional legibility vulnerability you identify.

v_leg_1 = analysis.add_vulnerability(
    name='[Short name for this vulnerability]',
    location='[Where in the regime is this located? Article numbers, section references, etc.]',
    description='[A short description of what this vulnerability is.]',
    rationale='[A paragraph explaining your reasoning for the scores below. This is where you document the analytical judgment that produced the scores.]',
    beneficiaries='[Who benefits from this vulnerability remaining unaddressed? Optional.]',
     impacted_populations='[Who bears the costs of this vulnerability? Optional.]',
    
    # Legibility sub-metrics (0-4)
    upstream_visibility=0,
    process_specification=0,
    inherited_trust=0,
    verification_authority=0,
    
    # Other dimensions for this vulnerability — score these too if relevant.
    # If this vulnerability is purely a legibility issue, leave others at 0.
    # In practice, most vulnerabilities score across multiple dimensions.
    
    accountability_inclusion_ratio=0,
    domain_authority_coverage=0,
    affected_party_standing=0,
    coordination_specificity=0,
    
    threshold_definition=0,
    obligation_bindingness=0,
    deferred_process_density=0,
    exception_architecture=0,
    
    pattern_recognition_assignment=0,
    detection_capability_requirement=0,
    trigger_specificity=0,
    response_architecture_coherence=0,
    
    mechanism_existence=0,
    mechanism_accessibility=0,
    cost_distribution=0,
    pre_enforcement_recourse=0,
)

print(f'Added: {v_leg_1.name} | Base score: {v_leg_1.base_score()} ({v_leg_1.severity_label()})')

# %% [markdown]
# ---
#
# ## Examination 2: Architecture Analysis
#
# **Question:** Which actors will be held accountable for outcomes the regime addresses, but are not structurally required in its coordination architecture? Which domain authorities are implicated by conditions the regime depends on, but excluded from the architecture?
#
# Run the cell below to see the scoring criteria:

# %%
show_criteria('architecture')

# %%
# Add an architecture vulnerability

v_arch_1 = analysis.add_vulnerability(
    name='[Short name]',
    location='[Where in the regime]',
    description='[Short description]',
    rationale='[Reasoning for the scores]',
    beneficiaries='',
     impacted_populations='',
    
    upstream_visibility=0,
    process_specification=0,
    inherited_trust=0,
    verification_authority=0,
    
    # Architecture sub-metrics (0-4)
    accountability_inclusion_ratio=0,
    domain_authority_coverage=0,
    affected_party_standing=0,
    coordination_specificity=0,
    
    threshold_definition=0,
    obligation_bindingness=0,
    deferred_process_density=0,
    exception_architecture=0,
    
    pattern_recognition_assignment=0,
    detection_capability_requirement=0,
    trigger_specificity=0,
    response_architecture_coherence=0,
    
    mechanism_existence=0,
    mechanism_accessibility=0,
    cost_distribution=0,
    pre_enforcement_recourse=0,
)

print(f'Added: {v_arch_1.name} | Base score: {v_arch_1.base_score()} ({v_arch_1.severity_label()})')

# %% [markdown]
# ---
#
# ## Examination 3: Specificity Analysis
#
# **Question:** Where does the text use language that signals commitment without enforceable specificity? Where are obligations stated in ways that defer accountability to undefined future processes? Where do thresholds, triggers, or required actions depend on judgments that no authority is required to make?
#
# Run the cell below to see the scoring criteria:

# %%
show_criteria('specificity')

# %%
# Add a specificity vulnerability

v_spec_1 = analysis.add_vulnerability(
    name='[Short name]',
    location='[Where in the regime]',
    description='[Short description]',
    rationale='[Reasoning for the scores]',
    beneficiaries='',
     impacted_populations='',
    
    upstream_visibility=0,
    process_specification=0,
    inherited_trust=0,
    verification_authority=0,
    
    accountability_inclusion_ratio=0,
    domain_authority_coverage=0,
    affected_party_standing=0,
    coordination_specificity=0,
    
    # Specificity sub-metrics (0-4)
    threshold_definition=0,
    obligation_bindingness=0,
    deferred_process_density=0,
    exception_architecture=0,
    
    pattern_recognition_assignment=0,
    detection_capability_requirement=0,
    trigger_specificity=0,
    response_architecture_coherence=0,
    
    mechanism_existence=0,
    mechanism_accessibility=0,
    cost_distribution=0,
    pre_enforcement_recourse=0,
)

print(f'Added: {v_spec_1.name} | Base score: {v_spec_1.base_score()} ({v_spec_1.severity_label()})')

# %% [markdown]
# ---
#
# ## Examination 4: Pattern Responsibility Analysis
#
# **Question:** Where does the regime assume someone is monitoring for conditions or patterns that should trigger response, without assigning that monitoring function to a specific authority?
#
# Run the cell below to see the scoring criteria:

# %%
show_criteria('pattern_responsibility')

# %%
# Add a pattern responsibility vulnerability

v_pat_1 = analysis.add_vulnerability(
    name='[Short name]',
    location='[Where in the regime]',
    description='[Short description]',
    rationale='[Reasoning for the scores]',
    beneficiaries='',
     impacted_populations='',
    
    upstream_visibility=0,
    process_specification=0,
    inherited_trust=0,
    verification_authority=0,
    
    accountability_inclusion_ratio=0,
    domain_authority_coverage=0,
    affected_party_standing=0,
    coordination_specificity=0,
    
    threshold_definition=0,
    obligation_bindingness=0,
    deferred_process_density=0,
    exception_architecture=0,
    
    # Pattern responsibility sub-metrics (0-4)
    pattern_recognition_assignment=0,
    detection_capability_requirement=0,
    trigger_specificity=0,
    response_architecture_coherence=0,
    
    mechanism_existence=0,
    mechanism_accessibility=0,
    cost_distribution=0,
    pre_enforcement_recourse=0,
)

print(f'Added: {v_pat_1.name} | Base score: {v_pat_1.base_score()} ({v_pat_1.severity_label()})')

# %% [markdown]
# ---
#
# ## Examination 5: Recourse Analysis
#
# **Question:** What mechanisms exist for affected parties to surface concerns or contest decisions? Are those mechanisms accessible without resources affected parties are unlikely to have? Who bears the cost of triggering enforcement?
#
# Run the cell below to see the scoring criteria:

# %%
show_criteria('recourse')

# %%
# Add a recourse vulnerability

v_rec_1 = analysis.add_vulnerability(
    name='[Short name]',
    location='[Where in the regime]',
    description='[Short description]',
    rationale='[Reasoning for the scores]',
    beneficiaries='',
      impacted_populations='',
    
    upstream_visibility=0,
    process_specification=0,
    inherited_trust=0,
    verification_authority=0,
    
    accountability_inclusion_ratio=0,
    domain_authority_coverage=0,
    affected_party_standing=0,
    coordination_specificity=0,
    
    threshold_definition=0,
    obligation_bindingness=0,
    deferred_process_density=0,
    exception_architecture=0,
    
    pattern_recognition_assignment=0,
    detection_capability_requirement=0,
    trigger_specificity=0,
    response_architecture_coherence=0,
    
    # Recourse sub-metrics (0-4)
    mechanism_existence=0,
    mechanism_accessibility=0,
    cost_distribution=0,
    pre_enforcement_recourse=0,
)

print(f'Added: {v_rec_1.name} | Base score: {v_rec_1.base_score()} ({v_rec_1.severity_label()})')

# %% [markdown]
# ---
#
# ## Outputs
#
# Once you have added all the vulnerabilities you identified, run the cells below to view the summary, visualisations, and generate the final report.

# %%
# Summary table of all vulnerabilities
analysis.summary_table()

# %%
# Comparison chart of all vulnerabilities by base score
comparison_chart(analysis)

# %%
# Radar chart for a specific vulnerability — change the variable name as needed
radar_chart(v_leg_1)

# %%
# Generate a markdown report and CSV export
# Outputs will be saved to the ../outputs/ folder
generate_report(analysis, output_dir='../outputs')

# %% [markdown]
# ---
#
# *VMPD v1.0 — Bhavyatta Bhardwaj, Danuma, 2026*
#
# *Citation: Bhardwaj, B. (2026). Vulnerability Management for Policy Design (VMPD): A Methodology for Diagnosing Structural Failures in Governance Regimes, v1.0. Zenodo. DOI: 10.5281/zenodo.19958977
# May 1, 2026*
